# %% [markdown]
# # Step 1 :Import pandas and Read the csv file

# %%
import  pandas as pd 
df = pd.read_csv("data.csv")
import matplotlib.pyplot as plt

# %%
df
# Out:
#          ID Age_group Age  Gender PAQ605 Body Mass Index  \
# 0     73564     Adult           2      2            35.7
# 1     73568     Adult  26       2      2            20.3
# 2     73576     Adult  16       1      2            23.2
# 3     73577     Adult           1      2
# 4     73580     Adult  38       2      1            35.9
# ...     ...       ...  ..     ...    ...             ...
# 2273  83711     Adult  38       2      2            33.5
# 2274  83712     Adult  61       1                     30
# 2275  83713     Adult  34       1      2            23.7
# 2276  83718     Adult  60       2      2            27.4
# 2277  83727     Adult  26       1                   24.5
#
#      Blood Glucose after fasting Diabetic or not Respondent's Oral  \
# 0                            110               2               150
# 1                             89               2
# 2                             89               2                68
# ...

# %% [markdown]
# # Step 2:  Data Analysis

# %%
df.head(15) # first 15 rows
# Out:
#        ID Age_group Age  Gender PAQ605 Body Mass Index  \
# 0   73564     Adult           2      2            35.7
# 1   73568     Adult  26       2      2            20.3
# 2   73576     Adult  16       1      2            23.2
# 3   73577     Adult           1      2
# 4   73580     Adult  38       2      1            35.9
# 5   73581     Adult  50       1      2            23.6
# 6   73587     Adult  14       1      2            38.7
# 7   73596     Adult  57       2      2            38.3
# 8   73607    Senior  75       1      2            38.9
# 9   73610     Adult  43       1      1            28.9
# 10  73618     Adult  54       2      2            32.7
# 11  73619     Adult  36       2      1            27.3
# 12  73621    Senior  80       1      2            24.6
# 13  73633     Adult  43       2      2            30.5
# 14  73639    Senior  71       1      2            30.3
#
#    Blood Glucose after fasting Diabetic or not Respondent's Oral  \
# ...

# %%
df.tail(15) # last 15 rows
# Out:
#          ID Age_group Age  Gender PAQ605 Body Mass Index  \
# 2263  83673     Adult  17       2      2            29.1
# 2264  83677     Adult  18       2      2            26.8
# 2265  83678     Adult  42       2      2            18.3
# 2266  83679     Adult  14       2      2            19.3
# 2267  83683     Adult  33       2      2              30
# 2268  83692    Senior  68       1      2            19.1
# 2269  83694     Adult  36       2      2            25.3
# 2270  83699     Adult  37       2      2            20.8
# 2271  83702    Senior  80       2      2
# 2272  83707     Adult  18       1      2            22.5
# 2273  83711     Adult  38       2      2            33.5
# 2274  83712     Adult  61       1                     30
# 2275  83713     Adult  34       1      2            23.7
# 2276  83718     Adult  60       2      2            27.4
# 2277  83727     Adult  26       1                   24.5
#
# ...

# %%
df.shape # show the number of  rows and columns
# Out:
# (2278, 10)

# %%
df.sample(15) # random 15 rows
# Out:
#          ID Age_group Age  Gender PAQ605 Body Mass Index  \
# 1461  80226     Adult  30       1      1              22
# 1373  79863     Adult  45       1      1            27.1
# 1235  79176     Adult  55       1      1            30.1
# 320   75023     Adult  27       1      1            26.1
# 1214  79091     Adult  38       2      2            28.3
# 1692  81149     Adult  34       1      2            26.2
# 1744  81366     Adult  38       1      1            28.4
# 2143  83052    Senior  76       1      2            28.1
# 1546  80535     Adult  25       2      2            27.3
# 234   74653     Adult  29       2      2            30.6
# 22    73668     Adult  30       2      2            32.3
# 48    73790     Adult  59       1      2            30.2
# 515   75928     Adult  31       2      2            31.9
# 812   77228     Adult  27       1      2            30.7
# 1553  80570    Senior  74       2      2            21.3
#
# ...

# %% [markdown]
# # Changing the name of the Columns

# %%
df.rename(columns={'ID':'Name' , 'Gender':'Male'},inplace=True) # rename the columns name

# %%
df
# Out:
#        Name Age_group Age  Male PAQ605 Body Mass Index  \
# 0     73564     Adult         2      2            35.7
# 1     73568     Adult  26     2      2            20.3
# 2     73576     Adult  16     1      2            23.2
# 3     73577     Adult         1      2
# 4     73580     Adult  38     2      1            35.9
# ...     ...       ...  ..   ...    ...             ...
# 2273  83711     Adult  38     2      2            33.5
# 2274  83712     Adult  61     1                     30
# 2275  83713     Adult  34     1      2            23.7
# 2276  83718     Adult  60     2      2            27.4
# 2277  83727     Adult  26     1                   24.5
#
#      Blood Glucose after fasting Diabetic or not Respondent's Oral  \
# 0                            110               2               150
# 1                             89               2
# 2                             89               2                68
# ...

# %%
df.info() # data type
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2278 entries, 0 to 2277
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Name                         2278 non-null   int64
#  1   Age_group                    2278 non-null   object
#  2   Age                          2278 non-null   object
#  3   Male                         2278 non-null   int64
#  4   PAQ605                       2278 non-null   object
#  5   Body Mass Index              2278 non-null   object
#  6   Blood Glucose after fasting  2278 non-null   object
#  7   Diabetic or not              2278 non-null   object
#  8   Respondent's Oral            2278 non-null   object
#  9   Blood Insulin Levels         2278 non-null   float64
# dtypes: float64(1), int64(2), object(7)
# memory usage: 178.1+ KB

# %%
df.describe(include='all') # summary of data
# Out:
#                 Name Age_group   Age         Male PAQ605 Body Mass Index  \
# count    2278.000000      2278  2278  2278.000000   2278            2278
# unique           NaN         2    70          NaN      5             341
# top              NaN     Adult    80          NaN      2            23.9
# freq             NaN      1914   107          NaN   1866              26
# mean    78691.853819       NaN   NaN     1.511414    NaN             NaN
# std      2921.365151       NaN   NaN     0.499979    NaN             NaN
# min     73564.000000       NaN   NaN     1.000000    NaN             NaN
# 25%     76171.750000       NaN   NaN     1.000000    NaN             NaN
# 50%     78749.000000       NaN   NaN     2.000000    NaN             NaN
# 75%     81213.500000       NaN   NaN     2.000000    NaN             NaN
# max     83727.000000       NaN   NaN     2.000000    NaN             NaN
#
#        Blood Glucose after fasting Diabetic or not Respondent's Oral  \
# ...

# %% [markdown]
# # Mean ,Median and Mode

# %%
df['Name'].mean() # show the Arthimetics mean of the Name
# Out:
# 78691.8538191396

# %%
df['Name'].mode() # show the most repetted value in Name
# Out:
# 0       73564
# 1       73568
# 2       73576
# 3       73577
# 4       73580
#         ...
# 2273    83711
# 2274    83712
# 2275    83713
# 2276    83718
# 2277    83727
# Name: Name, Length: 2278, dtype: int64

# %%
df['Name'].median() # show the middle value
# Out:
# 78749.0

# %% [markdown]
# # Element Slicing using Loc and iLoc

# %%
df.iloc[0 ,3]
# Out:
# 2

# %%
df.loc[2,'Name']
# Out:
# 73576

# %%
df.loc[1 , 'Body Mass Index']
# Out:
# '20.3'

# %%
df.loc[[1,3,5],['Name','Blood Glucose after fasting']]
# Out:
#     Name Blood Glucose after fasting
# 1  73568                          89
# 3  73577                         104
# 5  73581                         110

# %%
df.iloc[[0,1],[0,1]]
# Out:
#     Name Age_group
# 0  73564     Adult
# 1  73568     Adult

# %% [markdown]
# # Data Cleaning

# %%
df.isnull()
# Out:
#        Name  Age_group    Age   Male  PAQ605  Body Mass Index  \
# 0     False      False  False  False   False            False
# 1     False      False  False  False   False            False
# 2     False      False  False  False   False            False
# 3     False      False  False  False   False            False
# 4     False      False  False  False   False            False
# ...     ...        ...    ...    ...     ...              ...
# 2273  False      False  False  False   False            False
# 2274  False      False  False  False   False            False
# 2275  False      False  False  False   False            False
# 2276  False      False  False  False   False            False
# 2277  False      False  False  False   False            False
#
#       Blood Glucose after fasting  Diabetic or not  Respondent's Oral  \
# 0                           False            False              False
# 1                           False            False              False
# ...

# %%
df.isnull().sum()
# Out:
# Name                           0
# Age_group                      0
# Age                            0
# Male                           0
# PAQ605                         0
# Body Mass Index                0
# Blood Glucose after fasting    0
# Diabetic or not                0
# Respondent's Oral              0
# Blood Insulin Levels           0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.isnull().any(axis=1)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2273    False
# 2274    False
# 2275    False
# 2276    False
# 2277    False
# Length: 2278, dtype: bool

# %%
df.isnull().all(axis=1)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2273    False
# 2274    False
# 2275    False
# 2276    False
# 2277    False
# Length: 2278, dtype: bool

# %%
df.isnull().any()
# Out:
# Name                           False
# Age_group                      False
# Age                            False
# Male                           False
# PAQ605                         False
# Body Mass Index                False
# Blood Glucose after fasting    False
# Diabetic or not                False
# Respondent's Oral              False
# Blood Insulin Levels           False
# dtype: bool

# %%
df["Name"].fillna(df["Name"].mean)
# Out:
# 0       73564
# 1       73568
# 2       73576
# 3       73577
# 4       73580
#         ...
# 2273    83711
# 2274    83712
# 2275    83713
# 2276    83718
# 2277    83727
# Name: Name, Length: 2278, dtype: int64

# %%
df['Name'].fillna(df['Name'].mode)
# Out:
# 0       73564
# 1       73568
# 2       73576
# 3       73577
# 4       73580
#         ...
# 2273    83711
# 2274    83712
# 2275    83713
# 2276    83718
# 2277    83727
# Name: Name, Length: 2278, dtype: int64

# %%
df['Name'].fillna(df['Name'].median)
# Out:
# 0       73564
# 1       73568
# 2       73576
# 3       73577
# 4       73580
#         ...
# 2273    83711
# 2274    83712
# 2275    83713
# 2276    83718
# 2277    83727
# Name: Name, Length: 2278, dtype: int64

# %%
df.groupby('Name')['Male'].sum() # show the sum of name  and  male
# Out:
# Name
# 73564    2
# 73568    2
# 73576    1
# 73577    1
# 73580    2
#         ..
# 83711    2
# 83712    1
# 83713    1
# 83718    2
# 83727    1
# Name: Male, Length: 2278, dtype: int64

# %% [markdown]
# # Visualization

# %%
df['Age'].value_counts().plot(kind="bar") # show the bar chart
plt.show()

# %%
df['Name'].value_counts().plot(kind="line") # show the line chart
# Out:
# <Axes: xlabel='Name'>

# %%
df["Body Mass Index"].value_counts().plot(kind='hist',title='Histogram Chart') # show the histogram chat
plt.show()

# %%
df['Age'].value_counts().plot(kind="pie") # show the pie chart
# Out:
# <Axes: ylabel='count'>

# %%
df['Body Mass Index'].value_counts().plot(kind="barh") # show the barh chart
# Out:
# <Axes: ylabel='Body Mass Index'>
